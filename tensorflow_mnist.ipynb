# %%
# TensoFlow for multipy layer perceptrons
# this cell's code is adopted from Udacity

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
import math

tf.reset_default_graph()

learning_rate = 0.001
n_input = 784  # MNIST data input (img shape: 28*28)
n_classes = 10  # MNIST total classes (0-9 digits)

# Import MNIST data
mnist = input_data.read_data_sets('.', one_hot=True)

# Features and Labels
features = tf.placeholder(tf.float32, [None, n_input])
labels = tf.placeholder(tf.float32, [None, n_classes])

# Weights & bias
weights = tf.Variable(tf.random_normal([n_input, n_classes]))
bias = tf.Variable(tf.random_normal([n_classes]))

# Logits - xW + b
logits = tf.add(tf.matmul(features, weights), bias)

# Define loss and optimizer
cost = tf.reduce_mean(\
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
    .minimize(cost)

# Calculate accuracy
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(labels, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

save_file = './train_model.ckpt'
batch_size = 128
n_epochs = 100

saver = tf.train.Saver()

# Launch the graph
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # Training cycle
    for epoch in range(n_epochs):
        total_batch = math.ceil(mnist.train.num_examples / batch_size)

        # Loop over all batches
        for i in range(total_batch):
            batch_features, batch_labels = mnist.train.next_batch(batch_size)
            sess.run(
                optimizer,
                feed_dict={features: batch_features, labels: batch_labels})

        # Print status for every 10 epochs
        if epoch % 10 == 0:
            valid_accuracy = sess.run(
                accuracy,
                feed_dict={
                    features: mnist.validation.images,
                    labels: mnist.validation.labels})
            print('Epoch {:<3} - Validation Accuracy: {}'.format(
                epoch,
                valid_accuracy))

    # Save the model
    saver.save(sess, save_file)
    print('Trained Model Saved.')
    
saver = tf.train.Saver()

# Launch the graph
with tf.Session() as sess:
    saver.restore(sess, save_file)

    test_accuracy = sess.run(
        accuracy,
        feed_dict={features: mnist.test.images, labels: mnist.test.labels})

print('Test Accuracy: {}'.format(test_accuracy))

# %%
# Tensorflow for CNN from scratch
# this cell's code is adopted from Udacity

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./minist", one_hot=True, reshape=False)

# parameters
learning_rate = 0.00001
epochs = 10
batch_size = 128

# number of samples to calculate validation and accuracy
test_valid_size = 256

# network parameters
n_classes = 10
dropout = 0.75

# weights and biases
# the shape of the filter weight is (height, width, input_depth, output_depth)
weights = {
    'wc1': tf.Variable(tf.random_normal([5, 5, 1, 32])),
    'wc2': tf.Variable(tf.random_normal([5, 5, 32, 64])),
    'wd1': tf.Variable(tf.random_normal([7*7*64, 1024])),
    'out': tf.Variable(tf.random_normal([1024, n_classes]))}

# the shape of the filter bias is (output_depth,)
biases = {
    'bc1': tf.Variable(tf.random_normal([32])),
    'bc2': tf.Variable(tf.random_normal([64])),
    'bd1': tf.Variable(tf.random_normal([1024])),
    'out': tf.Variable(tf.random_normal([n_classes]))}

# stride for each dimension (batch_size, input_height, input_width, depth)
# generally always set the stride for batch and input_channels
# i.e. the first and fourth element in the strides array to be 1
# This ensures that the model uses all batches and input channels
# It's good practice to remove the batches or channels you want to skip
# from the data set rather than use a stride to skip them
#
# tf.nn.conv2d requires the input be 4D (batch_size, height, width, depth)


def conv2d(x, W, b, strides=1):
    x = tf.nn.conv2d(x, W, strides=[1, strides, strides, 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    # tf.add() doesn't work when the tensors aren't the same shape
    return tf.nn.relu(x)


def maxpool2d(x, k=2):
    return tf.nn.max_pool(x, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='SAME')


def conv_net(x, weights, biases, dropout):
    # layer 1 - 28*28*1 to 14*14*32
    conv1 = conv2d(x, weights['wc1'], biases['bc1'])
    conv1 = maxpool2d(conv1, k=2)

    # layer 2 - 14*14*32 to 7*7*64
    conv2 = conv2d(conv1, weights['wc2'], biases['bc2'])
    conv2 = maxpool2d(conv2, k=2)

    # fully connected layer - 7*7*64 to 1024
    # tensor.get_shape().as_list() will return the shape of the tensor as a list
    fc1 = tf.reshape(conv2, [-1, weights['wd1'].get_shape().as_list()[0]])
    fc1 = tf.add(tf.matmul(fc1, weights['wd1']), biases['bd1'])
    fc1 = tf.nn.relu(fc1)
    fc1 = tf.nn.dropout(fc1, dropout)

    # output layer
    out = tf.add(tf.matmul(fc1, weights['out']), biases['out'])
    return out


# session
x = tf.placeholder(tf.float32, [None, 28, 28, 1])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32)

# model
logits = conv_net(x, weights, biases, keep_prob)

# define loss and optimizer
cost = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
    .minimize(cost)

# accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initializing the viriables
init = tf.global_variables_initializer()

# launch the graph
with tf.Session() as sess:
    sess.run(init)

    for epoch in range(epochs):
        for batch in range(mnist.train.num_examples//batch_size):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: dropout
            })

            # calculate batch loss and accuracy
            loss = sess.run(cost, feed_dict={
                x: batch_x,
                y: batch_y,
                keep_prob: 1.})
            valid_acc = sess.run(accuracy, feed_dict={
                x: mnist.validation.images[:test_valid_size],
                y: mnist.validation.labels[:test_valid_size],
                keep_prob: 1.})

            print('Epoch {:>2}, Batch {:>3} - loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                  epoch + 1,
                  batch + 1,
                  loss,
                  valid_acc))

        test_acc = sess.run(accuracy, feed_dict={
            x: mnist.test.images[:test_valid_size],
            y: mnist.test.labels[:test_valid_size],
            keep_prob: 1.})
        print('Testing Accuracy: {}'.format(test_acc))
# Out:
# Extracting ./minist\train-images-idx3-ubyte.gz
# Extracting ./minist\train-labels-idx1-ubyte.gz
# Extracting ./minist\t10k-images-idx3-ubyte.gz
# Extracting ./minist\t10k-labels-idx1-ubyte.gz
# Epoch  1, Batch   1 - loss: 44921.2109 Validation Accuracy: 0.117188
# Epoch  1, Batch   2 - loss: 39512.6172 Validation Accuracy: 0.132812
# Epoch  1, Batch   3 - loss: 38796.0234 Validation Accuracy: 0.136719
# Epoch  1, Batch   4 - loss: 33993.9766 Validation Accuracy: 0.144531
# Epoch  1, Batch   5 - loss: 32297.1289 Validation Accuracy: 0.156250
# Epoch  1, Batch   6 - loss: 28180.9531 Validation Accuracy: 0.156250
# Epoch  1, Batch   7 - loss: 27998.1484 Validation Accuracy: 0.175781
# Epoch  1, Batch   8 - loss: 22116.1465 Validation Accuracy: 0.191406
# Epoch  1, Batch   9 - loss: 19747.3555 Validation Accuracy: 0.203125
# Epoch  1, Batch  10 - loss: 19602.3672 Validation Accuracy: 0.203125
# Epoch  1, Batch  11 - loss: 19429.8281 Validation Accuracy: 0.207031
# Epoch  1, Batch  12 - loss: 17874.4492 Validation Accuracy: 0.226562
# Epoch  1, Batch  13 - loss: 20684.0078 Validation Accuracy: 0.261719
# Epoch  1, Batch  14 - loss: 20714.3203 Validation Accuracy: 0.257812
# Epoch  1, Batch  15 - loss: 18567.7207 Validation Accuracy: 0.261719
# Epoch  1, Batch  16 - loss: 15979.0762 Validation Accuracy: 0.265625
# Epoch  1, Batch  17 - loss: 16828.2305 Validation Accuracy: 0.281250
# Epoch  1, Batch  18 - loss: 21717.5449 Validation Accuracy: 0.277344
# Epoch  1, Batch  19 - loss: 19177.9336 Validation Accuracy: 0.308594
# Epoch  1, Batch  20 - loss: 20092.7188 Validation Accuracy: 0.304688
# Epoch  1, Batch  21 - loss: 18863.9355 Validation Accuracy: 0.316406
# Epoch  1, Batch  22 - loss: 14558.8320 Validation Accuracy: 0.335938
# Epoch  1, Batch  23 - loss: 14737.3438 Validation Accuracy: 0.343750
# Epoch  1, Batch  24 - loss: 17244.1387 Validation Accuracy: 0.363281
# Epoch  1, Batch  25 - loss: 11209.9277 Validation Accuracy: 0.363281
# Epoch  1, Batch  26 - loss: 14997.7754 Validation Accuracy: 0.378906
# Epoch  1, Batch  27 - loss: 12117.2285 Validation Accuracy: 0.386719
# Epoch  1, Batch  28 - loss:  9457.6748 Validation Accuracy: 0.406250
# Epoch  1, Batch  29 - loss: 12763.5781 Validation Accuracy: 0.398438
# Epoch  1, Batch  30 - loss: 13038.9766 Validation Accuracy: 0.425781
# Epoch  1, Batch  31 - loss: 12183.2148 Validation Accuracy: 0.429688
# Epoch  1, Batch  32 - loss: 11369.9297 Validation Accuracy: 0.421875
# Epoch  1, Batch  33 - loss: 12750.2598 Validation Accuracy: 0.414062
# Epoch  1, Batch  34 - loss: 10108.3252 Validation Accuracy: 0.433594
# Epoch  1, Batch  35 - loss: 10856.4746 Validation Accuracy: 0.433594
# Epoch  1, Batch  36 - loss: 11714.2969 Validation Accuracy: 0.441406
# Epoch  1, Batch  37 - loss:  9155.9775 Validation Accuracy: 0.445312
# Epoch  1, Batch  38 - loss:  9550.2402 Validation Accuracy: 0.472656
# Epoch  1, Batch  39 - loss:  8701.3037 Validation Accuracy: 0.468750
# Epoch  1, Batch  40 - loss:  7383.7422 Validation Accuracy: 0.472656
# Epoch  1, Batch  41 - loss: 11352.9443 Validation Accuracy: 0.488281
# Epoch  1, Batch  42 - loss: 10786.3545 Validation Accuracy: 0.464844
# Epoch  1, Batch  43 - loss: 10109.0547 Validation Accuracy: 0.460938
# Epoch  1, Batch  44 - loss:  7759.4834 Validation Accuracy: 0.492188
# Epoch  1, Batch  45 - loss:  8274.7500 Validation Accuracy: 0.496094
# Epoch  1, Batch  46 - loss:  7050.3682 Validation Accuracy: 0.488281
# Epoch  1, Batch  47 - loss:  7025.7153 Validation Accuracy: 0.496094
# Epoch  1, Batch  48 - loss:  7370.9575 Validation Accuracy: 0.496094
# Epoch  1, Batch  49 - loss:  8876.8975 Validation Accuracy: 0.500000
# Epoch  1, Batch  50 - loss:  9562.7832 Validation Accuracy: 0.500000
# Epoch  1, Batch  51 - loss:  9436.7959 Validation Accuracy: 0.519531
# Epoch  1, Batch  52 - loss: 11430.8457 Validation Accuracy: 0.496094
# Epoch  1, Batch  53 - loss:  8695.4883 Validation Accuracy: 0.519531
# Epoch  1, Batch  54 - loss:  8892.6338 Validation Accuracy: 0.523438
# Epoch  1, Batch  55 - loss:  9927.6523 Validation Accuracy: 0.523438
# Epoch  1, Batch  56 - loss:  5472.1709 Validation Accuracy: 0.542969
# Epoch  1, Batch  57 - loss:  8501.1250 Validation Accuracy: 0.570312
# Epoch  1, Batch  58 - loss:  8736.7246 Validation Accuracy: 0.570312
# Epoch  1, Batch  59 - loss:  7748.2324 Validation Accuracy: 0.570312
# Epoch  1, Batch  60 - loss:  8600.1191 Validation Accuracy: 0.570312
# Epoch  1, Batch  61 - loss:  7713.4341 Validation Accuracy: 0.562500
# Epoch  1, Batch  62 - loss:  7285.4893 Validation Accuracy: 0.566406
# Epoch  1, Batch  63 - loss:  8015.9404 Validation Accuracy: 0.566406
# Epoch  1, Batch  64 - loss:  8300.7383 Validation Accuracy: 0.582031
# Epoch  1, Batch  65 - loss:  7025.0635 Validation Accuracy: 0.593750
# Epoch  1, Batch  66 - loss:  6140.9175 Validation Accuracy: 0.597656
# Epoch  1, Batch  67 - loss:  6152.2852 Validation Accuracy: 0.605469
# Epoch  1, Batch  68 - loss:  6242.1753 Validation Accuracy: 0.597656
# Epoch  1, Batch  69 - loss:  6336.5112 Validation Accuracy: 0.601562
# Epoch  1, Batch  70 - loss:  7799.2905 Validation Accuracy: 0.609375
# Epoch  1, Batch  71 - loss:  7588.0049 Validation Accuracy: 0.601562
# Epoch  1, Batch  72 - loss:  6945.2656 Validation Accuracy: 0.601562
# Epoch  1, Batch  73 - loss:  7910.6094 Validation Accuracy: 0.601562
# Epoch  1, Batch  74 - loss:  8966.6973 Validation Accuracy: 0.617188
# Epoch  1, Batch  75 - loss:  7946.0825 Validation Accuracy: 0.617188
# Epoch  1, Batch  76 - loss: 11619.8154 Validation Accuracy: 0.593750
# Epoch  1, Batch  77 - loss:  8607.8057 Validation Accuracy: 0.609375
# Epoch  1, Batch  78 - loss:  6107.1460 Validation Accuracy: 0.625000
# Epoch  1, Batch  79 - loss:  4758.5898 Validation Accuracy: 0.636719
# Epoch  1, Batch  80 - loss:  6107.3301 Validation Accuracy: 0.628906
# Epoch  1, Batch  81 - loss:  4869.6758 Validation Accuracy: 0.625000
# Epoch  1, Batch  82 - loss:  6459.3726 Validation Accuracy: 0.621094
# Epoch  1, Batch  83 - loss:  5399.2949 Validation Accuracy: 0.636719
# Epoch  1, Batch  84 - loss:  6207.2832 Validation Accuracy: 0.652344
# Epoch  1, Batch  85 - loss:  7266.4658 Validation Accuracy: 0.660156
# Epoch  1, Batch  86 - loss:  6063.5254 Validation Accuracy: 0.656250
# Epoch  1, Batch  87 - loss:  6603.5259 Validation Accuracy: 0.664062
# Epoch  1, Batch  88 - loss:  5075.5400 Validation Accuracy: 0.664062
# Epoch  1, Batch  89 - loss:  7494.1816 Validation Accuracy: 0.667969
# Epoch  1, Batch  90 - loss:  5669.7983 Validation Accuracy: 0.671875
# Epoch  1, Batch  91 - loss:  4960.9219 Validation Accuracy: 0.656250
# Epoch  1, Batch  92 - loss:  6061.6201 Validation Accuracy: 0.664062
# Epoch  1, Batch  93 - loss:  6307.1553 Validation Accuracy: 0.664062
# Epoch  1, Batch  94 - loss:  6545.0352 Validation Accuracy: 0.664062
# Epoch  1, Batch  95 - loss:  7245.4180 Validation Accuracy: 0.656250
# Epoch  1, Batch  96 - loss:  5742.2490 Validation Accuracy: 0.671875
# Epoch  1, Batch  97 - loss:  6640.1768 Validation Accuracy: 0.675781
# Epoch  1, Batch  98 - loss:  6784.7051 Validation Accuracy: 0.667969
# Epoch  1, Batch  99 - loss:  6928.7471 Validation Accuracy: 0.679688
# Epoch  1, Batch 100 - loss:  7791.0322 Validation Accuracy: 0.667969
# Epoch  1, Batch 101 - loss:  5088.4272 Validation Accuracy: 0.675781
# Epoch  1, Batch 102 - loss:  5150.6182 Validation Accuracy: 0.687500
# Epoch  1, Batch 103 - loss:  3657.4238 Validation Accuracy: 0.695312
# Epoch  1, Batch 104 - loss:  4231.7852 Validation Accuracy: 0.687500
# Epoch  1, Batch 105 - loss:  5465.5947 Validation Accuracy: 0.675781
# Epoch  1, Batch 106 - loss:  4809.6772 Validation Accuracy: 0.683594
# Epoch  1, Batch 107 - loss:  4515.1455 Validation Accuracy: 0.675781
# Epoch  1, Batch 108 - loss:  5958.7261 Validation Accuracy: 0.691406
# Epoch  1, Batch 109 - loss:  3758.2732 Validation Accuracy: 0.687500
# Epoch  1, Batch 110 - loss:  4643.3682 Validation Accuracy: 0.675781
# Epoch  1, Batch 111 - loss:  5662.9448 Validation Accuracy: 0.687500
# Epoch  1, Batch 112 - loss:  4626.6514 Validation Accuracy: 0.671875
# Epoch  1, Batch 113 - loss:  3597.4365 Validation Accuracy: 0.679688
# Epoch  1, Batch 114 - loss:  5327.0527 Validation Accuracy: 0.679688
# Epoch  1, Batch 115 - loss:  3513.8711 Validation Accuracy: 0.691406
# Epoch  1, Batch 116 - loss:  3182.0183 Validation Accuracy: 0.687500
# Epoch  1, Batch 117 - loss:  7053.3682 Validation Accuracy: 0.691406
# Epoch  1, Batch 118 - loss:  6314.3032 Validation Accuracy: 0.691406
# Epoch  1, Batch 119 - loss:  4518.9072 Validation Accuracy: 0.691406
# Epoch  1, Batch 120 - loss:  4298.7822 Validation Accuracy: 0.699219
# Epoch  1, Batch 121 - loss:  3913.1890 Validation Accuracy: 0.699219
# Epoch  1, Batch 122 - loss:  4521.3359 Validation Accuracy: 0.710938
# Epoch  1, Batch 123 - loss:  4217.9395 Validation Accuracy: 0.707031
# Epoch  1, Batch 124 - loss:  4273.1582 Validation Accuracy: 0.695312
# Epoch  1, Batch 125 - loss:  4448.4639 Validation Accuracy: 0.718750
# Epoch  1, Batch 126 - loss:  4047.5767 Validation Accuracy: 0.707031
# Epoch  1, Batch 127 - loss:  3972.2524 Validation Accuracy: 0.707031
# Epoch  1, Batch 128 - loss:  2998.6738 Validation Accuracy: 0.710938
# Epoch  1, Batch 129 - loss:  4290.6152 Validation Accuracy: 0.707031
# Epoch  1, Batch 130 - loss:  2853.3779 Validation Accuracy: 0.707031
# Epoch  1, Batch 131 - loss:  3340.7217 Validation Accuracy: 0.710938
# Epoch  1, Batch 132 - loss:  4159.3867 Validation Accuracy: 0.714844
# Epoch  1, Batch 133 - loss:  3706.1152 Validation Accuracy: 0.722656
# Epoch  1, Batch 134 - loss:  5865.2822 Validation Accuracy: 0.718750
# Epoch  1, Batch 135 - loss:  4774.4189 Validation Accuracy: 0.718750
# Epoch  1, Batch 136 - loss:  3243.8694 Validation Accuracy: 0.722656
# Epoch  1, Batch 137 - loss:  4419.9585 Validation Accuracy: 0.722656
# Epoch  1, Batch 138 - loss:  4195.7876 Validation Accuracy: 0.722656
# Epoch  1, Batch 139 - loss:  3658.0686 Validation Accuracy: 0.718750
# Epoch  1, Batch 140 - loss:  3843.3110 Validation Accuracy: 0.722656
# Epoch  1, Batch 141 - loss:  4375.9478 Validation Accuracy: 0.714844
# Epoch  1, Batch 142 - loss:  3896.5530 Validation Accuracy: 0.726562
# Epoch  1, Batch 143 - loss:  3274.6477 Validation Accuracy: 0.722656
# Epoch  1, Batch 144 - loss:  3568.7007 Validation Accuracy: 0.722656
# Epoch  1, Batch 145 - loss:  4163.3389 Validation Accuracy: 0.726562
# Epoch  1, Batch 146 - loss:  4262.5503 Validation Accuracy: 0.738281
# Epoch  1, Batch 147 - loss:  4374.0918 Validation Accuracy: 0.726562
# Epoch  1, Batch 148 - loss:  3584.5088 Validation Accuracy: 0.734375
# Epoch  1, Batch 149 - loss:  4232.7788 Validation Accuracy: 0.730469
# Epoch  1, Batch 150 - loss:  2886.5347 Validation Accuracy: 0.734375
# Epoch  1, Batch 151 - loss:  5267.6016 Validation Accuracy: 0.742188
# Epoch  1, Batch 152 - loss:  2314.3350 Validation Accuracy: 0.734375
# Epoch  1, Batch 153 - loss:  3265.2202 Validation Accuracy: 0.730469
# Epoch  1, Batch 154 - loss:  4630.9756 Validation Accuracy: 0.734375
# Epoch  1, Batch 155 - loss:  4752.2666 Validation Accuracy: 0.738281
# Epoch  1, Batch 156 - loss:  2881.6936 Validation Accuracy: 0.742188
# Epoch  1, Batch 157 - loss:  3393.8125 Validation Accuracy: 0.746094
# Epoch  1, Batch 158 - loss:  3389.1514 Validation Accuracy: 0.738281
# Epoch  1, Batch 159 - loss:  3574.7271 Validation Accuracy: 0.746094
# Epoch  1, Batch 160 - loss:  2541.0754 Validation Accuracy: 0.734375
# Epoch  1, Batch 161 - loss:  3183.8496 Validation Accuracy: 0.726562
# Epoch  1, Batch 162 - loss:  3884.1826 Validation Accuracy: 0.730469
# Epoch  1, Batch 163 - loss:  4545.9214 Validation Accuracy: 0.750000
# Epoch  1, Batch 164 - loss:  3414.3828 Validation Accuracy: 0.746094
# Epoch  1, Batch 165 - loss:  3075.3716 Validation Accuracy: 0.750000
# Epoch  1, Batch 166 - loss:  2809.1787 Validation Accuracy: 0.742188
# Epoch  1, Batch 167 - loss:  3318.0627 Validation Accuracy: 0.750000
# Epoch  1, Batch 168 - loss:  5503.4292 Validation Accuracy: 0.750000
# Epoch  1, Batch 169 - loss:  4642.0752 Validation Accuracy: 0.750000
# Epoch  1, Batch 170 - loss:  3732.6221 Validation Accuracy: 0.738281
# Epoch  1, Batch 171 - loss:  3297.6628 Validation Accuracy: 0.738281
# Epoch  1, Batch 172 - loss:  4195.2217 Validation Accuracy: 0.738281
# Epoch  1, Batch 173 - loss:  4249.6260 Validation Accuracy: 0.738281
# Epoch  1, Batch 174 - loss:  4343.9648 Validation Accuracy: 0.750000
# Epoch  1, Batch 175 - loss:  3613.8523 Validation Accuracy: 0.750000
# Epoch  1, Batch 176 - loss:  3531.3423 Validation Accuracy: 0.750000
# Epoch  1, Batch 177 - loss:  2284.7478 Validation Accuracy: 0.742188
# Epoch  1, Batch 178 - loss:  2685.7046 Validation Accuracy: 0.742188
# Epoch  1, Batch 179 - loss:  3672.8560 Validation Accuracy: 0.742188
# Epoch  1, Batch 180 - loss:  2253.8813 Validation Accuracy: 0.750000
# Epoch  1, Batch 181 - loss:  2341.2292 Validation Accuracy: 0.742188
# Epoch  1, Batch 182 - loss:  1997.6262 Validation Accuracy: 0.738281
# Epoch  1, Batch 183 - loss:  2797.2446 Validation Accuracy: 0.750000
# Epoch  1, Batch 184 - loss:  2685.0825 Validation Accuracy: 0.742188
# Epoch  1, Batch 185 - loss:  3227.2378 Validation Accuracy: 0.757812
# Epoch  1, Batch 186 - loss:  2968.5361 Validation Accuracy: 0.753906
# Epoch  1, Batch 187 - loss:  2781.9919 Validation Accuracy: 0.757812
# Epoch  1, Batch 188 - loss:  3773.2961 Validation Accuracy: 0.753906
# Epoch  1, Batch 189 - loss:  3807.3191 Validation Accuracy: 0.773438
# Epoch  1, Batch 190 - loss:  3532.8711 Validation Accuracy: 0.761719
# Epoch  1, Batch 191 - loss:  3193.0962 Validation Accuracy: 0.769531
# Epoch  1, Batch 192 - loss:  3139.2844 Validation Accuracy: 0.773438
# Epoch  1, Batch 193 - loss:  3130.0444 Validation Accuracy: 0.769531
# Epoch  1, Batch 194 - loss:  4427.5107 Validation Accuracy: 0.761719
# Epoch  1, Batch 195 - loss:  4764.6118 Validation Accuracy: 0.765625
# Epoch  1, Batch 196 - loss:  3055.4067 Validation Accuracy: 0.769531
# Epoch  1, Batch 197 - loss:  3947.1763 Validation Accuracy: 0.769531
# Epoch  1, Batch 198 - loss:  2200.6262 Validation Accuracy: 0.761719
# Epoch  1, Batch 199 - loss:  2456.4131 Validation Accuracy: 0.761719
# Epoch  1, Batch 200 - loss:  3221.7229 Validation Accuracy: 0.761719
# Epoch  1, Batch 201 - loss:  4161.1704 Validation Accuracy: 0.761719
# Epoch  1, Batch 202 - loss:  2627.6665 Validation Accuracy: 0.769531
# Epoch  1, Batch 203 - loss:  4957.8877 Validation Accuracy: 0.765625
# Epoch  1, Batch 204 - loss:  3896.2144 Validation Accuracy: 0.750000
# Epoch  1, Batch 205 - loss:  2717.4893 Validation Accuracy: 0.761719
# Epoch  1, Batch 206 - loss:  3932.8545 Validation Accuracy: 0.765625
# Epoch  1, Batch 207 - loss:  2600.7830 Validation Accuracy: 0.765625
# Epoch  1, Batch 208 - loss:  2573.2695 Validation Accuracy: 0.757812
# Epoch  1, Batch 209 - loss:  4464.8916 Validation Accuracy: 0.753906
# Epoch  1, Batch 210 - loss:  2894.0405 Validation Accuracy: 0.765625
# Epoch  1, Batch 211 - loss:  2774.7751 Validation Accuracy: 0.765625
# Epoch  1, Batch 212 - loss:  3013.5688 Validation Accuracy: 0.765625
# Epoch  1, Batch 213 - loss:  2440.7266 Validation Accuracy: 0.769531
# Epoch  1, Batch 214 - loss:  3696.1782 Validation Accuracy: 0.769531
# Epoch  1, Batch 215 - loss:  4237.5938 Validation Accuracy: 0.765625
# Epoch  1, Batch 216 - loss:  2411.4871 Validation Accuracy: 0.765625
# Epoch  1, Batch 217 - loss:  2804.9507 Validation Accuracy: 0.761719
# Epoch  1, Batch 218 - loss:  2669.1235 Validation Accuracy: 0.769531
# Epoch  1, Batch 219 - loss:  2352.2266 Validation Accuracy: 0.765625
# Epoch  1, Batch 220 - loss:  2776.9927 Validation Accuracy: 0.765625
# Epoch  1, Batch 221 - loss:  2338.2749 Validation Accuracy: 0.765625
# Epoch  1, Batch 222 - loss:  3168.1360 Validation Accuracy: 0.773438
# Epoch  1, Batch 223 - loss:  2921.5544 Validation Accuracy: 0.765625
# Epoch  1, Batch 224 - loss:  1429.1738 Validation Accuracy: 0.753906
# Epoch  1, Batch 225 - loss:  3862.3416 Validation Accuracy: 0.761719
# Epoch  1, Batch 226 - loss:  1967.3008 Validation Accuracy: 0.765625
# Epoch  1, Batch 227 - loss:  2800.2339 Validation Accuracy: 0.769531
# Epoch  1, Batch 228 - loss:  2812.8030 Validation Accuracy: 0.765625
# Epoch  1, Batch 229 - loss:  2174.6372 Validation Accuracy: 0.765625
# Epoch  1, Batch 230 - loss:  3284.8901 Validation Accuracy: 0.769531
# Epoch  1, Batch 231 - loss:  2401.8076 Validation Accuracy: 0.769531
# Epoch  1, Batch 232 - loss:  3134.0229 Validation Accuracy: 0.761719
# Epoch  1, Batch 233 - loss:  3167.2495 Validation Accuracy: 0.769531
# Epoch  1, Batch 234 - loss:  3779.4670 Validation Accuracy: 0.769531
# Epoch  1, Batch 235 - loss:  2556.2407 Validation Accuracy: 0.773438
# Epoch  1, Batch 236 - loss:  2574.9927 Validation Accuracy: 0.777344
# Epoch  1, Batch 237 - loss:  2454.6357 Validation Accuracy: 0.773438
# Epoch  1, Batch 238 - loss:  2191.9561 Validation Accuracy: 0.777344
# Epoch  1, Batch 239 - loss:  2534.4736 Validation Accuracy: 0.785156
# Epoch  1, Batch 240 - loss:  2358.7463 Validation Accuracy: 0.777344
# Epoch  1, Batch 241 - loss:  2001.1436 Validation Accuracy: 0.777344
# Epoch  1, Batch 242 - loss:  2480.2075 Validation Accuracy: 0.777344
# Epoch  1, Batch 243 - loss:  3572.2300 Validation Accuracy: 0.773438
# Epoch  1, Batch 244 - loss:  2392.3755 Validation Accuracy: 0.777344
# Epoch  1, Batch 245 - loss:  2538.0769 Validation Accuracy: 0.769531
# Epoch  1, Batch 246 - loss:  2728.7185 Validation Accuracy: 0.781250
# Epoch  1, Batch 247 - loss:  2764.4705 Validation Accuracy: 0.773438
# Epoch  1, Batch 248 - loss:  2292.3887 Validation Accuracy: 0.773438
# Epoch  1, Batch 249 - loss:  3286.2017 Validation Accuracy: 0.761719
# Epoch  1, Batch 250 - loss:  2552.8062 Validation Accuracy: 0.765625
# Epoch  1, Batch 251 - loss:  3204.1099 Validation Accuracy: 0.765625
# Epoch  1, Batch 252 - loss:  1660.1748 Validation Accuracy: 0.765625
# Epoch  1, Batch 253 - loss:  3045.7993 Validation Accuracy: 0.753906
# Epoch  1, Batch 254 - loss:  3914.8267 Validation Accuracy: 0.769531
# Epoch  1, Batch 255 - loss:  3172.5215 Validation Accuracy: 0.777344
# Epoch  1, Batch 256 - loss:  1866.3599 Validation Accuracy: 0.777344
# Epoch  1, Batch 257 - loss:  3064.8726 Validation Accuracy: 0.769531
# Epoch  1, Batch 258 - loss:  1749.5248 Validation Accuracy: 0.777344
# Epoch  1, Batch 259 - loss:  3160.3965 Validation Accuracy: 0.769531
# Epoch  1, Batch 260 - loss:  1786.3273 Validation Accuracy: 0.773438
# Epoch  1, Batch 261 - loss:  2875.1458 Validation Accuracy: 0.785156
# Epoch  1, Batch 262 - loss:  2384.7573 Validation Accuracy: 0.781250
# Epoch  1, Batch 263 - loss:  2656.0237 Validation Accuracy: 0.773438
# Epoch  1, Batch 264 - loss:  2022.5425 Validation Accuracy: 0.777344
# Epoch  1, Batch 265 - loss:  2064.3394 Validation Accuracy: 0.769531
# Epoch  1, Batch 266 - loss:  1640.9895 Validation Accuracy: 0.773438
# Epoch  1, Batch 267 - loss:  1457.2485 Validation Accuracy: 0.781250
# Epoch  1, Batch 268 - loss:  2468.5823 Validation Accuracy: 0.769531
# Epoch  1, Batch 269 - loss:  3257.1484 Validation Accuracy: 0.777344
# Epoch  1, Batch 270 - loss:  2232.0769 Validation Accuracy: 0.777344
# Epoch  1, Batch 271 - loss:  1917.3535 Validation Accuracy: 0.773438
# Epoch  1, Batch 272 - loss:  2933.1099 Validation Accuracy: 0.777344
# Epoch  1, Batch 273 - loss:  2802.7510 Validation Accuracy: 0.777344
# Epoch  1, Batch 274 - loss:  2969.7947 Validation Accuracy: 0.777344
# Epoch  1, Batch 275 - loss:  2309.3625 Validation Accuracy: 0.777344
# Epoch  1, Batch 276 - loss:  1481.0170 Validation Accuracy: 0.781250
# Epoch  1, Batch 277 - loss:  2404.3596 Validation Accuracy: 0.777344
# Epoch  1, Batch 278 - loss:  3515.6265 Validation Accuracy: 0.777344
# Epoch  1, Batch 279 - loss:  2410.4976 Validation Accuracy: 0.777344
# Epoch  1, Batch 280 - loss:  2019.1588 Validation Accuracy: 0.777344
# Epoch  1, Batch 281 - loss:  1755.9835 Validation Accuracy: 0.781250
# Epoch  1, Batch 282 - loss:  2874.0439 Validation Accuracy: 0.781250
# Epoch  1, Batch 283 - loss:  1994.6543 Validation Accuracy: 0.785156
# Epoch  1, Batch 284 - loss:  3100.7803 Validation Accuracy: 0.789062
# Epoch  1, Batch 285 - loss:  1979.0366 Validation Accuracy: 0.781250
# Epoch  1, Batch 286 - loss:  2337.5686 Validation Accuracy: 0.781250
# Epoch  1, Batch 287 - loss:  2097.4307 Validation Accuracy: 0.781250
# Epoch  1, Batch 288 - loss:  1999.2351 Validation Accuracy: 0.781250
# Epoch  1, Batch 289 - loss:  1507.8446 Validation Accuracy: 0.781250
# Epoch  1, Batch 290 - loss:  2515.6846 Validation Accuracy: 0.781250
# Epoch  1, Batch 291 - loss:  2614.6052 Validation Accuracy: 0.789062
# Epoch  1, Batch 292 - loss:  2847.6184 Validation Accuracy: 0.792969
# Epoch  1, Batch 293 - loss:  2423.8250 Validation Accuracy: 0.796875
# Epoch  1, Batch 294 - loss:  2381.3770 Validation Accuracy: 0.785156
# Epoch  1, Batch 295 - loss:  2560.2905 Validation Accuracy: 0.781250
# Epoch  1, Batch 296 - loss:  2538.9734 Validation Accuracy: 0.781250
# Epoch  1, Batch 297 - loss:  3323.3643 Validation Accuracy: 0.781250
# Epoch  1, Batch 298 - loss:  2192.7139 Validation Accuracy: 0.785156
# Epoch  1, Batch 299 - loss:  2041.0531 Validation Accuracy: 0.785156
# Epoch  1, Batch 300 - loss:  1035.5483 Validation Accuracy: 0.785156
# Epoch  1, Batch 301 - loss:  1535.1716 Validation Accuracy: 0.789062
# Epoch  1, Batch 302 - loss:  1265.1521 Validation Accuracy: 0.792969
# Epoch  1, Batch 303 - loss:  1687.6234 Validation Accuracy: 0.792969
# Epoch  1, Batch 304 - loss:  2438.7109 Validation Accuracy: 0.789062
# Epoch  1, Batch 305 - loss:  2483.3438 Validation Accuracy: 0.789062
# Epoch  1, Batch 306 - loss:  3065.1396 Validation Accuracy: 0.792969
# Epoch  1, Batch 307 - loss:  2654.2952 Validation Accuracy: 0.800781
# Epoch  1, Batch 308 - loss:  3125.8875 Validation Accuracy: 0.792969
# Epoch  1, Batch 309 - loss:  1682.2036 Validation Accuracy: 0.781250
# Epoch  1, Batch 310 - loss:  1650.6665 Validation Accuracy: 0.800781
# Epoch  1, Batch 311 - loss:  2016.2737 Validation Accuracy: 0.796875
# Epoch  1, Batch 312 - loss:  2627.1963 Validation Accuracy: 0.796875
# Epoch  1, Batch 313 - loss:  2059.2432 Validation Accuracy: 0.796875
# Epoch  1, Batch 314 - loss:  2179.0732 Validation Accuracy: 0.792969
# Epoch  1, Batch 315 - loss:  1473.5710 Validation Accuracy: 0.789062
# Epoch  1, Batch 316 - loss:  2163.8093 Validation Accuracy: 0.789062
# Epoch  1, Batch 317 - loss:  2555.4094 Validation Accuracy: 0.792969
# Epoch  1, Batch 318 - loss:  1897.0559 Validation Accuracy: 0.792969
# Epoch  1, Batch 319 - loss:  2185.0305 Validation Accuracy: 0.796875
# Epoch  1, Batch 320 - loss:  3118.3662 Validation Accuracy: 0.800781
# Epoch  1, Batch 321 - loss:  2710.5173 Validation Accuracy: 0.789062
# Epoch  1, Batch 322 - loss:  2753.6497 Validation Accuracy: 0.789062
# Epoch  1, Batch 323 - loss:  2605.6167 Validation Accuracy: 0.792969
# Epoch  1, Batch 324 - loss:  1778.5200 Validation Accuracy: 0.792969
# Epoch  1, Batch 325 - loss:  1989.8494 Validation Accuracy: 0.796875
# Epoch  1, Batch 326 - loss:  2276.4336 Validation Accuracy: 0.796875
# Epoch  1, Batch 327 - loss:  2379.6331 Validation Accuracy: 0.781250
# Epoch  1, Batch 328 - loss:  1664.9219 Validation Accuracy: 0.789062
# Epoch  1, Batch 329 - loss:  1860.5070 Validation Accuracy: 0.785156
# Epoch  1, Batch 330 - loss:  2024.5178 Validation Accuracy: 0.792969
# Epoch  1, Batch 331 - loss:  3768.1641 Validation Accuracy: 0.792969
# Epoch  1, Batch 332 - loss:  2331.0725 Validation Accuracy: 0.792969
# Epoch  1, Batch 333 - loss:  1534.7832 Validation Accuracy: 0.792969
# Epoch  1, Batch 334 - loss:  2176.7383 Validation Accuracy: 0.789062
# Epoch  1, Batch 335 - loss:  1308.6165 Validation Accuracy: 0.789062
# Epoch  1, Batch 336 - loss:  2004.8538 Validation Accuracy: 0.789062
# Epoch  1, Batch 337 - loss:  1627.6656 Validation Accuracy: 0.792969
# Epoch  1, Batch 338 - loss:  1353.4519 Validation Accuracy: 0.785156
# Epoch  1, Batch 339 - loss:  2151.7205 Validation Accuracy: 0.781250
# Epoch  1, Batch 340 - loss:  1703.1777 Validation Accuracy: 0.785156
# Epoch  1, Batch 341 - loss:  1784.3087 Validation Accuracy: 0.785156
# Epoch  1, Batch 342 - loss:  1092.9258 Validation Accuracy: 0.789062
# Epoch  1, Batch 343 - loss:  1403.6632 Validation Accuracy: 0.785156
# Epoch  1, Batch 344 - loss:  3075.9683 Validation Accuracy: 0.792969
# Epoch  1, Batch 345 - loss:  2798.0967 Validation Accuracy: 0.789062
# Epoch  1, Batch 346 - loss:  1791.2998 Validation Accuracy: 0.792969
# Epoch  1, Batch 347 - loss:  1547.0598 Validation Accuracy: 0.792969
# Epoch  1, Batch 348 - loss:  3271.5625 Validation Accuracy: 0.785156
# Epoch  1, Batch 349 - loss:  3248.5427 Validation Accuracy: 0.781250
# Epoch  1, Batch 350 - loss:  1829.2390 Validation Accuracy: 0.785156
# Epoch  1, Batch 351 - loss:  1715.3389 Validation Accuracy: 0.785156
# Epoch  1, Batch 352 - loss:  1817.0345 Validation Accuracy: 0.792969
# Epoch  1, Batch 353 - loss:  1681.5496 Validation Accuracy: 0.789062
# Epoch  1, Batch 354 - loss:  2539.1624 Validation Accuracy: 0.785156
# Epoch  1, Batch 355 - loss:  2916.9307 Validation Accuracy: 0.785156
# Epoch  1, Batch 356 - loss:  1946.8131 Validation Accuracy: 0.785156
# Epoch  1, Batch 357 - loss:  1924.6621 Validation Accuracy: 0.785156
# Epoch  1, Batch 358 - loss:  2238.8079 Validation Accuracy: 0.785156
# Epoch  1, Batch 359 - loss:  1637.1357 Validation Accuracy: 0.785156
# Epoch  1, Batch 360 - loss:  1256.1479 Validation Accuracy: 0.792969
# Epoch  1, Batch 361 - loss:  2318.0762 Validation Accuracy: 0.792969
# Epoch  1, Batch 362 - loss:  2545.0850 Validation Accuracy: 0.789062
# Epoch  1, Batch 363 - loss:  2098.8923 Validation Accuracy: 0.789062
# Epoch  1, Batch 364 - loss:  1025.2402 Validation Accuracy: 0.785156
# Epoch  1, Batch 365 - loss:  1627.5192 Validation Accuracy: 0.789062
# Epoch  1, Batch 366 - loss:  1246.9688 Validation Accuracy: 0.796875
# Epoch  1, Batch 367 - loss:  1755.4875 Validation Accuracy: 0.796875
# Epoch  1, Batch 368 - loss:  2001.1284 Validation Accuracy: 0.796875
# Epoch  1, Batch 369 - loss:  2937.6709 Validation Accuracy: 0.800781
# Epoch  1, Batch 370 - loss:  1774.6459 Validation Accuracy: 0.800781
# Epoch  1, Batch 371 - loss:  1641.7062 Validation Accuracy: 0.792969
# Epoch  1, Batch 372 - loss:  1258.5100 Validation Accuracy: 0.789062
# Epoch  1, Batch 373 - loss:  1748.7888 Validation Accuracy: 0.792969
# Epoch  1, Batch 374 - loss:  2046.0249 Validation Accuracy: 0.800781
# Epoch  1, Batch 375 - loss:  2620.3081 Validation Accuracy: 0.792969
# Epoch  1, Batch 376 - loss:  1919.6377 Validation Accuracy: 0.796875
# Epoch  1, Batch 377 - loss:  1330.9070 Validation Accuracy: 0.796875
# Epoch  1, Batch 378 - loss:  1502.9952 Validation Accuracy: 0.800781
# Epoch  1, Batch 379 - loss:   987.6807 Validation Accuracy: 0.804688
# Epoch  1, Batch 380 - loss:  2263.2285 Validation Accuracy: 0.808594
# Epoch  1, Batch 381 - loss:  1268.8718 Validation Accuracy: 0.800781
# Epoch  1, Batch 382 - loss:  1745.6826 Validation Accuracy: 0.800781
# Epoch  1, Batch 383 - loss:  2235.5332 Validation Accuracy: 0.800781
# Epoch  1, Batch 384 - loss:  2179.3601 Validation Accuracy: 0.796875
# Epoch  1, Batch 385 - loss:  1362.9247 Validation Accuracy: 0.792969
# Epoch  1, Batch 386 - loss:  1956.2434 Validation Accuracy: 0.800781
# Epoch  1, Batch 387 - loss:  2278.9670 Validation Accuracy: 0.796875
# Epoch  1, Batch 388 - loss:  1284.8466 Validation Accuracy: 0.792969
# Epoch  1, Batch 389 - loss:  1494.1560 Validation Accuracy: 0.796875
# Epoch  1, Batch 390 - loss:  2554.1265 Validation Accuracy: 0.800781
# Epoch  1, Batch 391 - loss:  2278.0007 Validation Accuracy: 0.804688
# Epoch  1, Batch 392 - loss:   887.2982 Validation Accuracy: 0.804688
# Epoch  1, Batch 393 - loss:  1210.3270 Validation Accuracy: 0.804688
# Epoch  1, Batch 394 - loss:  1233.8206 Validation Accuracy: 0.800781
# Epoch  1, Batch 395 - loss:  2115.0015 Validation Accuracy: 0.800781
# Epoch  1, Batch 396 - loss:  1701.9884 Validation Accuracy: 0.800781
# Epoch  1, Batch 397 - loss:  1600.1208 Validation Accuracy: 0.796875
# Epoch  1, Batch 398 - loss:  1301.4075 Validation Accuracy: 0.796875
# Epoch  1, Batch 399 - loss:   899.5737 Validation Accuracy: 0.792969
# Epoch  1, Batch 400 - loss:  1242.2203 Validation Accuracy: 0.800781
# Epoch  1, Batch 401 - loss:  1469.1909 Validation Accuracy: 0.796875
# Epoch  1, Batch 402 - loss:  1861.6353 Validation Accuracy: 0.800781
# Epoch  1, Batch 403 - loss:  1752.4387 Validation Accuracy: 0.800781
# Epoch  1, Batch 404 - loss:  1943.0133 Validation Accuracy: 0.800781
# Epoch  1, Batch 405 - loss:  1396.4519 Validation Accuracy: 0.796875
# Epoch  1, Batch 406 - loss:   963.1136 Validation Accuracy: 0.792969
# Epoch  1, Batch 407 - loss:  2176.7202 Validation Accuracy: 0.792969
# Epoch  1, Batch 408 - loss:   930.6769 Validation Accuracy: 0.800781
# Epoch  1, Batch 409 - loss:  2280.1274 Validation Accuracy: 0.800781
# Epoch  1, Batch 410 - loss:  1159.5299 Validation Accuracy: 0.804688
# Epoch  1, Batch 411 - loss:  1394.6672 Validation Accuracy: 0.804688
# Epoch  1, Batch 412 - loss:  1989.4114 Validation Accuracy: 0.808594
# Epoch  1, Batch 413 - loss:  1083.1914 Validation Accuracy: 0.812500
# Epoch  1, Batch 414 - loss:  1777.9949 Validation Accuracy: 0.812500
# Epoch  1, Batch 415 - loss:  1608.5413 Validation Accuracy: 0.812500
# Epoch  1, Batch 416 - loss:   608.8917 Validation Accuracy: 0.816406
# Epoch  1, Batch 417 - loss:  1232.1730 Validation Accuracy: 0.820312
# Epoch  1, Batch 418 - loss:  1239.5608 Validation Accuracy: 0.812500
# Epoch  1, Batch 419 - loss:  1499.4248 Validation Accuracy: 0.816406
# Epoch  1, Batch 420 - loss:  1229.3098 Validation Accuracy: 0.812500
# Epoch  1, Batch 421 - loss:  1234.9211 Validation Accuracy: 0.804688
# Epoch  1, Batch 422 - loss:   650.2425 Validation Accuracy: 0.800781
# Epoch  1, Batch 423 - loss:   535.8524 Validation Accuracy: 0.800781
# Epoch  1, Batch 424 - loss:   713.5330 Validation Accuracy: 0.796875
# Epoch  1, Batch 425 - loss:  3035.6030 Validation Accuracy: 0.796875
# Epoch  1, Batch 426 - loss:  1210.4919 Validation Accuracy: 0.785156
# Epoch  1, Batch 427 - loss:  1159.7417 Validation Accuracy: 0.781250
# Epoch  1, Batch 428 - loss:  2310.5039 Validation Accuracy: 0.785156
# Epoch  1, Batch 429 - loss:   435.8209 Validation Accuracy: 0.796875
# Testing Accuracy: 0.7734375
# Epoch  2, Batch   1 - loss:  1653.7229 Validation Accuracy: 0.792969
# Epoch  2, Batch   2 - loss:  1825.4255 Validation Accuracy: 0.796875
# Epoch  2, Batch   3 - loss:  1800.7280 Validation Accuracy: 0.800781
# Epoch  2, Batch   4 - loss:  1793.3684 Validation Accuracy: 0.796875
# Epoch  2, Batch   5 - loss:  1367.7250 Validation Accuracy: 0.785156
# Epoch  2, Batch   6 - loss:  2351.5933 Validation Accuracy: 0.792969
# Epoch  2, Batch   7 - loss:  1754.2906 Validation Accuracy: 0.800781
# Epoch  2, Batch   8 - loss:  1861.4275 Validation Accuracy: 0.804688
# Epoch  2, Batch   9 - loss:  1029.9683 Validation Accuracy: 0.792969
# Epoch  2, Batch  10 - loss:  1791.3806 Validation Accuracy: 0.800781
# Epoch  2, Batch  11 - loss:  1018.2139 Validation Accuracy: 0.796875
# Epoch  2, Batch  12 - loss:  1706.8203 Validation Accuracy: 0.808594
# Epoch  2, Batch  13 - loss:  1480.8740 Validation Accuracy: 0.804688
# Epoch  2, Batch  14 - loss:  2404.3667 Validation Accuracy: 0.804688
# Epoch  2, Batch  15 - loss:  1312.4312 Validation Accuracy: 0.812500
# Epoch  2, Batch  16 - loss:  2051.0781 Validation Accuracy: 0.816406
# Epoch  2, Batch  17 - loss:  1687.7037 Validation Accuracy: 0.812500
# Epoch  2, Batch  18 - loss:  1497.2441 Validation Accuracy: 0.808594
# Epoch  2, Batch  19 - loss:  1857.7380 Validation Accuracy: 0.808594
# Epoch  2, Batch  20 - loss:  1653.0562 Validation Accuracy: 0.812500
# Epoch  2, Batch  21 - loss:  2285.1426 Validation Accuracy: 0.808594
# Epoch  2, Batch  22 - loss:   745.7067 Validation Accuracy: 0.808594
# Epoch  2, Batch  23 - loss:  1339.8953 Validation Accuracy: 0.812500
# Epoch  2, Batch  24 - loss:  1382.7705 Validation Accuracy: 0.812500
# Epoch  2, Batch  25 - loss:  1816.6094 Validation Accuracy: 0.812500
# Epoch  2, Batch  26 - loss:  1630.9917 Validation Accuracy: 0.812500
# Epoch  2, Batch  27 - loss:  1971.9473 Validation Accuracy: 0.808594
# Epoch  2, Batch  28 - loss:  1821.7203 Validation Accuracy: 0.816406
# Epoch  2, Batch  29 - loss:  2665.5874 Validation Accuracy: 0.812500
# Epoch  2, Batch  30 - loss:  1672.7515 Validation Accuracy: 0.808594
# Epoch  2, Batch  31 - loss:  1525.7854 Validation Accuracy: 0.804688
# Epoch  2, Batch  32 - loss:  1719.5139 Validation Accuracy: 0.804688
# Epoch  2, Batch  33 - loss:  1533.0321 Validation Accuracy: 0.808594
# Epoch  2, Batch  34 - loss:  1523.2358 Validation Accuracy: 0.796875
# Epoch  2, Batch  35 - loss:  1598.2744 Validation Accuracy: 0.792969
# Epoch  2, Batch  36 - loss:  1494.2170 Validation Accuracy: 0.792969
# Epoch  2, Batch  37 - loss:  1725.3374 Validation Accuracy: 0.796875
# Epoch  2, Batch  38 - loss:  1906.8462 Validation Accuracy: 0.804688
# Epoch  2, Batch  39 - loss:  1752.7439 Validation Accuracy: 0.812500
# Epoch  2, Batch  40 - loss:  1884.7939 Validation Accuracy: 0.808594
# Epoch  2, Batch  41 - loss:  1884.5331 Validation Accuracy: 0.804688
# Epoch  2, Batch  42 - loss:  1462.1646 Validation Accuracy: 0.804688
# Epoch  2, Batch  43 - loss:   829.8361 Validation Accuracy: 0.812500
# Epoch  2, Batch  44 - loss:  1865.8179 Validation Accuracy: 0.812500
# Epoch  2, Batch  45 - loss:  1204.4489 Validation Accuracy: 0.808594
# Epoch  2, Batch  46 - loss:  1477.5754 Validation Accuracy: 0.808594
# Epoch  2, Batch  47 - loss:  1590.2847 Validation Accuracy: 0.804688
# Epoch  2, Batch  48 - loss:  1459.7509 Validation Accuracy: 0.812500
# Epoch  2, Batch  49 - loss:  2048.4551 Validation Accuracy: 0.816406
# Epoch  2, Batch  50 - loss:  1472.1261 Validation Accuracy: 0.820312
# Epoch  2, Batch  51 - loss:  1724.3549 Validation Accuracy: 0.812500
# Epoch  2, Batch  52 - loss:  1414.7173 Validation Accuracy: 0.812500
# Epoch  2, Batch  53 - loss:  1728.8220 Validation Accuracy: 0.808594
# Epoch  2, Batch  54 - loss:  1567.2419 Validation Accuracy: 0.808594
# Epoch  2, Batch  55 - loss:  1539.1575 Validation Accuracy: 0.816406
# Epoch  2, Batch  56 - loss:  1693.2371 Validation Accuracy: 0.816406
# Epoch  2, Batch  57 - loss:  1413.7043 Validation Accuracy: 0.808594
# Epoch  2, Batch  58 - loss:  2262.7927 Validation Accuracy: 0.820312
# Epoch  2, Batch  59 - loss:  1789.3787 Validation Accuracy: 0.816406
# Epoch  2, Batch  60 - loss:  1512.8862 Validation Accuracy: 0.812500
# Epoch  2, Batch  61 - loss:  1640.7947 Validation Accuracy: 0.804688
# Epoch  2, Batch  62 - loss:  1152.1775 Validation Accuracy: 0.812500
# Epoch  2, Batch  63 - loss:   948.3079 Validation Accuracy: 0.812500
# Epoch  2, Batch  64 - loss:  1363.5303 Validation Accuracy: 0.812500
# Epoch  2, Batch  65 - loss:  2001.8330 Validation Accuracy: 0.812500
# Epoch  2, Batch  66 - loss:  2015.4441 Validation Accuracy: 0.812500
# Epoch  2, Batch  67 - loss:   814.0243 Validation Accuracy: 0.816406
# Epoch  2, Batch  68 - loss:  1295.1873 Validation Accuracy: 0.804688
# Epoch  2, Batch  69 - loss:  1378.9082 Validation Accuracy: 0.804688
# Epoch  2, Batch  70 - loss:  2293.4866 Validation Accuracy: 0.804688
# Epoch  2, Batch  71 - loss:  1319.9424 Validation Accuracy: 0.804688
# Epoch  2, Batch  72 - loss:   845.7271 Validation Accuracy: 0.800781
# Epoch  2, Batch  73 - loss:  1833.2001 Validation Accuracy: 0.808594
# Epoch  2, Batch  74 - loss:  1017.7929 Validation Accuracy: 0.808594
# Epoch  2, Batch  75 - loss:  2088.4858 Validation Accuracy: 0.800781
# Epoch  2, Batch  76 - loss:  1592.5389 Validation Accuracy: 0.804688
# Epoch  2, Batch  77 - loss:  1292.5800 Validation Accuracy: 0.804688
# Epoch  2, Batch  78 - loss:  1317.0881 Validation Accuracy: 0.804688
# Epoch  2, Batch  79 - loss:  1654.5963 Validation Accuracy: 0.796875
# Epoch  2, Batch  80 - loss:  1165.5094 Validation Accuracy: 0.804688
# Epoch  2, Batch  81 - loss:  1123.9430 Validation Accuracy: 0.804688
# Epoch  2, Batch  82 - loss:  1341.1348 Validation Accuracy: 0.804688
# Epoch  2, Batch  83 - loss:  2241.9302 Validation Accuracy: 0.808594
# Epoch  2, Batch  84 - loss:  1626.5568 Validation Accuracy: 0.804688
# Epoch  2, Batch  85 - loss:  1396.3990 Validation Accuracy: 0.804688
# Epoch  2, Batch  86 - loss:  1202.4833 Validation Accuracy: 0.804688
# Epoch  2, Batch  87 - loss:  1380.4399 Validation Accuracy: 0.804688
# Epoch  2, Batch  88 - loss:  1861.4136 Validation Accuracy: 0.804688
# Epoch  2, Batch  89 - loss:  1684.9175 Validation Accuracy: 0.812500
# Epoch  2, Batch  90 - loss:  1387.2300 Validation Accuracy: 0.812500
# Epoch  2, Batch  91 - loss:  1289.7629 Validation Accuracy: 0.808594
# Epoch  2, Batch  92 - loss:   918.8320 Validation Accuracy: 0.816406
# Epoch  2, Batch  93 - loss:  1132.2346 Validation Accuracy: 0.816406
# Epoch  2, Batch  94 - loss:  1463.5342 Validation Accuracy: 0.812500
# Epoch  2, Batch  95 - loss:  1627.2676 Validation Accuracy: 0.816406
# Epoch  2, Batch  96 - loss:  1369.7374 Validation Accuracy: 0.816406
# Epoch  2, Batch  97 - loss:  1536.5682 Validation Accuracy: 0.824219
# Epoch  2, Batch  98 - loss:  1015.6835 Validation Accuracy: 0.828125
# Epoch  2, Batch  99 - loss:  1271.2329 Validation Accuracy: 0.824219
# Epoch  2, Batch 100 - loss:  1336.4695 Validation Accuracy: 0.824219
# Epoch  2, Batch 101 - loss:  1839.0601 Validation Accuracy: 0.824219
# Epoch  2, Batch 102 - loss:  1755.2977 Validation Accuracy: 0.816406
# Epoch  2, Batch 103 - loss:  1379.0125 Validation Accuracy: 0.816406
# Epoch  2, Batch 104 - loss:  1469.4224 Validation Accuracy: 0.816406
# Epoch  2, Batch 105 - loss:  1170.0446 Validation Accuracy: 0.816406
# Epoch  2, Batch 106 - loss:  1795.7212 Validation Accuracy: 0.820312
# Epoch  2, Batch 107 - loss:  1142.8253 Validation Accuracy: 0.820312
# Epoch  2, Batch 108 - loss:  1049.9247 Validation Accuracy: 0.824219
# Epoch  2, Batch 109 - loss:  1813.6062 Validation Accuracy: 0.824219
# Epoch  2, Batch 110 - loss:  2036.9175 Validation Accuracy: 0.820312
# Epoch  2, Batch 111 - loss:  1045.7826 Validation Accuracy: 0.824219
# Epoch  2, Batch 112 - loss:   950.8087 Validation Accuracy: 0.820312
# Epoch  2, Batch 113 - loss:  1300.8335 Validation Accuracy: 0.828125
# Epoch  2, Batch 114 - loss:  1371.1947 Validation Accuracy: 0.816406
# Epoch  2, Batch 115 - loss:  1346.2656 Validation Accuracy: 0.816406
# Epoch  2, Batch 116 - loss:  1337.4021 Validation Accuracy: 0.816406
# Epoch  2, Batch 117 - loss:  1405.8975 Validation Accuracy: 0.812500
# Epoch  2, Batch 118 - loss:   809.3111 Validation Accuracy: 0.812500
# Epoch  2, Batch 119 - loss:  1151.4934 Validation Accuracy: 0.816406
# Epoch  2, Batch 120 - loss:  1274.1003 Validation Accuracy: 0.816406
# Epoch  2, Batch 121 - loss:  1495.2200 Validation Accuracy: 0.820312
# Epoch  2, Batch 122 - loss:  2361.2705 Validation Accuracy: 0.816406
# Epoch  2, Batch 123 - loss:  1721.6334 Validation Accuracy: 0.816406
# Epoch  2, Batch 124 - loss:  1807.8516 Validation Accuracy: 0.820312
# Epoch  2, Batch 125 - loss:   912.4570 Validation Accuracy: 0.820312
# Epoch  2, Batch 126 - loss:  1691.7307 Validation Accuracy: 0.820312
# Epoch  2, Batch 127 - loss:  1770.6536 Validation Accuracy: 0.820312
# Epoch  2, Batch 128 - loss:  1605.9021 Validation Accuracy: 0.820312
# Epoch  2, Batch 129 - loss:   931.5444 Validation Accuracy: 0.816406
# Epoch  2, Batch 130 - loss:  1209.3989 Validation Accuracy: 0.820312
# Epoch  2, Batch 131 - loss:  1164.1699 Validation Accuracy: 0.820312
# Epoch  2, Batch 132 - loss:   860.8426 Validation Accuracy: 0.820312
# Epoch  2, Batch 133 - loss:  1128.7240 Validation Accuracy: 0.820312
# Epoch  2, Batch 134 - loss:   999.1394 Validation Accuracy: 0.824219
# Epoch  2, Batch 135 - loss:  1369.5488 Validation Accuracy: 0.824219
# Epoch  2, Batch 136 - loss:  1119.3713 Validation Accuracy: 0.824219
# Epoch  2, Batch 137 - loss:  1481.2053 Validation Accuracy: 0.824219
# Epoch  2, Batch 138 - loss:  1483.6589 Validation Accuracy: 0.824219
# Epoch  2, Batch 139 - loss:  1399.4500 Validation Accuracy: 0.824219
# Epoch  2, Batch 140 - loss:  1528.9266 Validation Accuracy: 0.824219
# Epoch  2, Batch 141 - loss:  1169.3218 Validation Accuracy: 0.832031
# Epoch  2, Batch 142 - loss:  1414.8644 Validation Accuracy: 0.824219
# Epoch  2, Batch 143 - loss:  1130.2305 Validation Accuracy: 0.828125
# Epoch  2, Batch 144 - loss:  1829.2285 Validation Accuracy: 0.824219
# Epoch  2, Batch 145 - loss:   999.5715 Validation Accuracy: 0.824219
# Epoch  2, Batch 146 - loss:  1394.6088 Validation Accuracy: 0.828125
# Epoch  2, Batch 147 - loss:  1481.7683 Validation Accuracy: 0.828125
# Epoch  2, Batch 148 - loss:  1147.1987 Validation Accuracy: 0.828125
# Epoch  2, Batch 149 - loss:  1686.1995 Validation Accuracy: 0.828125
# Epoch  2, Batch 150 - loss:  1457.6439 Validation Accuracy: 0.824219
# Epoch  2, Batch 151 - loss:  1354.1157 Validation Accuracy: 0.828125
# Epoch  2, Batch 152 - loss:  1244.6439 Validation Accuracy: 0.828125
# Epoch  2, Batch 153 - loss:   894.1795 Validation Accuracy: 0.828125
# Epoch  2, Batch 154 - loss:  1329.3843 Validation Accuracy: 0.820312
# Epoch  2, Batch 155 - loss:  1135.0117 Validation Accuracy: 0.824219
# Epoch  2, Batch 156 - loss:  1136.6693 Validation Accuracy: 0.824219
# Epoch  2, Batch 157 - loss:  1341.5747 Validation Accuracy: 0.820312
# Epoch  2, Batch 158 - loss:   930.7604 Validation Accuracy: 0.820312
# Epoch  2, Batch 159 - loss:  1124.9766 Validation Accuracy: 0.824219
# Epoch  2, Batch 160 - loss:  1134.4528 Validation Accuracy: 0.824219
# Epoch  2, Batch 161 - loss:  1488.6937 Validation Accuracy: 0.824219
# Epoch  2, Batch 162 - loss:  1252.5444 Validation Accuracy: 0.824219
# Epoch  2, Batch 163 - loss:  1326.1117 Validation Accuracy: 0.828125
# Epoch  2, Batch 164 - loss:  1164.7070 Validation Accuracy: 0.824219
# Epoch  2, Batch 165 - loss:  1463.0828 Validation Accuracy: 0.824219
# Epoch  2, Batch 166 - loss:  1676.3364 Validation Accuracy: 0.828125
# Epoch  2, Batch 167 - loss:  1072.0437 Validation Accuracy: 0.828125
# Epoch  2, Batch 168 - loss:  1006.3972 Validation Accuracy: 0.828125
# Epoch  2, Batch 169 - loss:   976.1854 Validation Accuracy: 0.832031
# Epoch  2, Batch 170 - loss:  1256.1631 Validation Accuracy: 0.832031
# Epoch  2, Batch 171 - loss:  1054.1355 Validation Accuracy: 0.824219
# Epoch  2, Batch 172 - loss:  1162.0186 Validation Accuracy: 0.824219
# Epoch  2, Batch 173 - loss:  1459.2458 Validation Accuracy: 0.824219
# Epoch  2, Batch 174 - loss:   829.9195 Validation Accuracy: 0.828125
# Epoch  2, Batch 175 - loss:   803.8220 Validation Accuracy: 0.824219
# Epoch  2, Batch 176 - loss:  1823.3260 Validation Accuracy: 0.828125
# Epoch  2, Batch 177 - loss:  1241.1003 Validation Accuracy: 0.828125
# Epoch  2, Batch 178 - loss:  1051.5205 Validation Accuracy: 0.832031
# Epoch  2, Batch 179 - loss:  1039.9985 Validation Accuracy: 0.824219
# Epoch  2, Batch 180 - loss:  1478.8718 Validation Accuracy: 0.824219
# Epoch  2, Batch 181 - loss:  1485.6488 Validation Accuracy: 0.828125
# Epoch  2, Batch 182 - loss:  1082.4340 Validation Accuracy: 0.832031
# Epoch  2, Batch 183 - loss:  1119.9996 Validation Accuracy: 0.820312
# Epoch  2, Batch 184 - loss:   933.6343 Validation Accuracy: 0.824219
# Epoch  2, Batch 185 - loss:  1219.9636 Validation Accuracy: 0.820312
# Epoch  2, Batch 186 - loss:  1106.6763 Validation Accuracy: 0.824219
# Epoch  2, Batch 187 - loss:   867.6738 Validation Accuracy: 0.820312
# Epoch  2, Batch 188 - loss:  1630.1486 Validation Accuracy: 0.820312
# Epoch  2, Batch 189 - loss:  1229.7791 Validation Accuracy: 0.820312
# Epoch  2, Batch 190 - loss:  1534.4125 Validation Accuracy: 0.820312
# Epoch  2, Batch 191 - loss:  1465.7985 Validation Accuracy: 0.816406
# Epoch  2, Batch 192 - loss:  1451.8765 Validation Accuracy: 0.812500
# Epoch  2, Batch 193 - loss:  1087.3392 Validation Accuracy: 0.812500
# Epoch  2, Batch 194 - loss:  1663.8807 Validation Accuracy: 0.828125
# Epoch  2, Batch 195 - loss:   978.3892 Validation Accuracy: 0.832031
# Epoch  2, Batch 196 - loss:  1575.1846 Validation Accuracy: 0.832031
# Epoch  2, Batch 197 - loss:  1493.1880 Validation Accuracy: 0.828125
# Epoch  2, Batch 198 - loss:  1902.4614 Validation Accuracy: 0.828125
# Epoch  2, Batch 199 - loss:   943.7469 Validation Accuracy: 0.824219
# Epoch  2, Batch 200 - loss:  1745.4252 Validation Accuracy: 0.828125
# Epoch  2, Batch 201 - loss:  1870.9661 Validation Accuracy: 0.824219
# Epoch  2, Batch 202 - loss:  1029.0190 Validation Accuracy: 0.820312
# Epoch  2, Batch 203 - loss:  1141.3811 Validation Accuracy: 0.820312
# Epoch  2, Batch 204 - loss:  1096.3754 Validation Accuracy: 0.820312
# Epoch  2, Batch 205 - loss:  1213.5547 Validation Accuracy: 0.820312
# Epoch  2, Batch 206 - loss:  1272.1692 Validation Accuracy: 0.824219
# Epoch  2, Batch 207 - loss:  1257.7549 Validation Accuracy: 0.828125
# Epoch  2, Batch 208 - loss:  1153.6838 Validation Accuracy: 0.824219
# Epoch  2, Batch 209 - loss:   832.1266 Validation Accuracy: 0.828125
# Epoch  2, Batch 210 - loss:   898.1494 Validation Accuracy: 0.828125
# Epoch  2, Batch 211 - loss:  1485.5764 Validation Accuracy: 0.832031
# Epoch  2, Batch 212 - loss:  1186.2749 Validation Accuracy: 0.832031
# Epoch  2, Batch 213 - loss:  1388.8350 Validation Accuracy: 0.835938
# Epoch  2, Batch 214 - loss:   699.0242 Validation Accuracy: 0.835938
# Epoch  2, Batch 215 - loss:   872.8913 Validation Accuracy: 0.832031
# Epoch  2, Batch 216 - loss:  1175.6631 Validation Accuracy: 0.835938
# Epoch  2, Batch 217 - loss:  1667.3115 Validation Accuracy: 0.832031
# Epoch  2, Batch 218 - loss:  1428.9890 Validation Accuracy: 0.835938
# Epoch  2, Batch 219 - loss:  1378.3547 Validation Accuracy: 0.835938
# Epoch  2, Batch 220 - loss:  1549.9854 Validation Accuracy: 0.835938
# Epoch  2, Batch 221 - loss:  1093.4126 Validation Accuracy: 0.832031
# Epoch  2, Batch 222 - loss:  1653.5608 Validation Accuracy: 0.835938
# Epoch  2, Batch 223 - loss:  1450.5652 Validation Accuracy: 0.828125
# Epoch  2, Batch 224 - loss:  1467.0294 Validation Accuracy: 0.832031
# Epoch  2, Batch 225 - loss:  1582.0782 Validation Accuracy: 0.832031
# Epoch  2, Batch 226 - loss:  1360.7366 Validation Accuracy: 0.828125
# Epoch  2, Batch 227 - loss:  1527.1689 Validation Accuracy: 0.828125
# Epoch  2, Batch 228 - loss:  1254.2732 Validation Accuracy: 0.832031
# Epoch  2, Batch 229 - loss:   638.4436 Validation Accuracy: 0.835938
# Epoch  2, Batch 230 - loss:   781.3867 Validation Accuracy: 0.835938
# Epoch  2, Batch 231 - loss:   848.1136 Validation Accuracy: 0.839844
# Epoch  2, Batch 232 - loss:   599.3223 Validation Accuracy: 0.832031
# Epoch  2, Batch 233 - loss:  1653.6611 Validation Accuracy: 0.835938
# Epoch  2, Batch 234 - loss:   869.5690 Validation Accuracy: 0.839844
# Epoch  2, Batch 235 - loss:  1564.5555 Validation Accuracy: 0.839844
# Epoch  2, Batch 236 - loss:  1286.0717 Validation Accuracy: 0.843750
# Epoch  2, Batch 237 - loss:  1354.9569 Validation Accuracy: 0.843750
# Epoch  2, Batch 238 - loss:  1077.2124 Validation Accuracy: 0.843750
# Epoch  2, Batch 239 - loss:   732.4271 Validation Accuracy: 0.839844
# Epoch  2, Batch 240 - loss:  1299.0502 Validation Accuracy: 0.843750
# Epoch  2, Batch 241 - loss:  1157.7319 Validation Accuracy: 0.835938
# Epoch  2, Batch 242 - loss:  1475.2491 Validation Accuracy: 0.839844
# Epoch  2, Batch 243 - loss:  1143.0250 Validation Accuracy: 0.839844
# Epoch  2, Batch 244 - loss:   886.6476 Validation Accuracy: 0.839844
# Epoch  2, Batch 245 - loss:  1810.9917 Validation Accuracy: 0.839844
# Epoch  2, Batch 246 - loss:  1489.2742 Validation Accuracy: 0.843750
# Epoch  2, Batch 247 - loss:  1235.4575 Validation Accuracy: 0.832031
# Epoch  2, Batch 248 - loss:   842.0579 Validation Accuracy: 0.835938
# Epoch  2, Batch 249 - loss:  1804.4915 Validation Accuracy: 0.835938
# Epoch  2, Batch 250 - loss:  1091.1658 Validation Accuracy: 0.832031
# Epoch  2, Batch 251 - loss:  1244.5745 Validation Accuracy: 0.832031
# Epoch  2, Batch 252 - loss:  1184.4443 Validation Accuracy: 0.828125
# Epoch  2, Batch 253 - loss:  1497.9978 Validation Accuracy: 0.832031
# Epoch  2, Batch 254 - loss:  1245.4535 Validation Accuracy: 0.835938
# Epoch  2, Batch 255 - loss:  1373.6340 Validation Accuracy: 0.835938
# Epoch  2, Batch 256 - loss:   981.5497 Validation Accuracy: 0.832031
# Epoch  2, Batch 257 - loss:  2027.9910 Validation Accuracy: 0.832031
# Epoch  2, Batch 258 - loss:  1381.1902 Validation Accuracy: 0.835938
# Epoch  2, Batch 259 - loss:  1288.7717 Validation Accuracy: 0.832031
# Epoch  2, Batch 260 - loss:  1133.0627 Validation Accuracy: 0.835938
# Epoch  2, Batch 261 - loss:  1010.3285 Validation Accuracy: 0.835938
# Epoch  2, Batch 262 - loss:   988.4990 Validation Accuracy: 0.835938
# Epoch  2, Batch 263 - loss:  1373.8239 Validation Accuracy: 0.839844
# ...
# Epoch 10, Batch 199 - loss:   327.0435 Validation Accuracy: 0.890625
# Epoch 10, Batch 200 - loss:   304.1982 Validation Accuracy: 0.890625
# Epoch 10, Batch 201 - loss:   371.9436 Validation Accuracy: 0.882812
# Epoch 10, Batch 202 - loss:   176.8772 Validation Accuracy: 0.890625
# Epoch 10, Batch 203 - loss:   416.8649 Validation Accuracy: 0.882812
# Epoch 10, Batch 204 - loss:   335.1942 Validation Accuracy: 0.882812
# Epoch 10, Batch 205 - loss:   159.2048 Validation Accuracy: 0.886719
# Epoch 10, Batch 206 - loss:   271.1821 Validation Accuracy: 0.886719
# Epoch 10, Batch 207 - loss:    85.7163 Validation Accuracy: 0.882812
# Epoch 10, Batch 208 - loss:   399.7169 Validation Accuracy: 0.882812
# Epoch 10, Batch 209 - loss:   303.7007 Validation Accuracy: 0.882812
# Epoch 10, Batch 210 - loss:   397.2238 Validation Accuracy: 0.878906
# Epoch 10, Batch 211 - loss:   287.5452 Validation Accuracy: 0.878906
# Epoch 10, Batch 212 - loss:   277.6601 Validation Accuracy: 0.886719
# Epoch 10, Batch 213 - loss:   370.7734 Validation Accuracy: 0.890625
# Epoch 10, Batch 214 - loss:   213.2676 Validation Accuracy: 0.894531
# Epoch 10, Batch 215 - loss:   201.4695 Validation Accuracy: 0.894531
# Epoch 10, Batch 216 - loss:   391.8972 Validation Accuracy: 0.894531
# Epoch 10, Batch 217 - loss:   204.7450 Validation Accuracy: 0.890625
# Epoch 10, Batch 218 - loss:   375.8603 Validation Accuracy: 0.894531
# Epoch 10, Batch 219 - loss:   276.8253 Validation Accuracy: 0.894531
# Epoch 10, Batch 220 - loss:   326.0160 Validation Accuracy: 0.894531
# Epoch 10, Batch 221 - loss:   184.5081 Validation Accuracy: 0.894531
# Epoch 10, Batch 222 - loss:   117.3023 Validation Accuracy: 0.894531
# Epoch 10, Batch 223 - loss:   271.6126 Validation Accuracy: 0.894531
# Epoch 10, Batch 224 - loss:   499.9526 Validation Accuracy: 0.894531
# Epoch 10, Batch 225 - loss:   358.2678 Validation Accuracy: 0.890625
# Epoch 10, Batch 226 - loss:   311.5425 Validation Accuracy: 0.890625
# Epoch 10, Batch 227 - loss:   268.3275 Validation Accuracy: 0.890625
# Epoch 10, Batch 228 - loss:   181.5938 Validation Accuracy: 0.886719
# Epoch 10, Batch 229 - loss:   317.9056 Validation Accuracy: 0.890625
# Epoch 10, Batch 230 - loss:   266.6319 Validation Accuracy: 0.886719
# Epoch 10, Batch 231 - loss:   448.0871 Validation Accuracy: 0.890625
# Epoch 10, Batch 232 - loss:   355.4109 Validation Accuracy: 0.886719
# Epoch 10, Batch 233 - loss:   136.7087 Validation Accuracy: 0.890625
# Epoch 10, Batch 234 - loss:   236.9776 Validation Accuracy: 0.886719
# Epoch 10, Batch 235 - loss:   301.2030 Validation Accuracy: 0.890625
# Epoch 10, Batch 236 - loss:   209.0270 Validation Accuracy: 0.886719
# Epoch 10, Batch 237 - loss:   287.6695 Validation Accuracy: 0.890625
# Epoch 10, Batch 238 - loss:   168.2318 Validation Accuracy: 0.890625
# Epoch 10, Batch 239 - loss:   252.9111 Validation Accuracy: 0.890625
# Epoch 10, Batch 240 - loss:   461.4783 Validation Accuracy: 0.890625
# Epoch 10, Batch 241 - loss:   529.4027 Validation Accuracy: 0.890625
# Epoch 10, Batch 242 - loss:   358.3733 Validation Accuracy: 0.886719
# Epoch 10, Batch 243 - loss:   225.6712 Validation Accuracy: 0.886719
# Epoch 10, Batch 244 - loss:   472.3942 Validation Accuracy: 0.890625
# Epoch 10, Batch 245 - loss:   238.0325 Validation Accuracy: 0.886719
# Epoch 10, Batch 246 - loss:   287.0056 Validation Accuracy: 0.886719
# Epoch 10, Batch 247 - loss:   203.5672 Validation Accuracy: 0.886719
# Epoch 10, Batch 248 - loss:   266.6177 Validation Accuracy: 0.886719
# Epoch 10, Batch 249 - loss:   401.1562 Validation Accuracy: 0.890625
# Epoch 10, Batch 250 - loss:   154.7072 Validation Accuracy: 0.878906
# Epoch 10, Batch 251 - loss:   240.1791 Validation Accuracy: 0.882812
# Epoch 10, Batch 252 - loss:   248.4391 Validation Accuracy: 0.882812
# Epoch 10, Batch 253 - loss:   347.9427 Validation Accuracy: 0.886719
# Epoch 10, Batch 254 - loss:   286.2352 Validation Accuracy: 0.882812
# Epoch 10, Batch 255 - loss:   298.9637 Validation Accuracy: 0.886719
# Epoch 10, Batch 256 - loss:   260.4477 Validation Accuracy: 0.886719
# Epoch 10, Batch 257 - loss:   345.6926 Validation Accuracy: 0.886719
# Epoch 10, Batch 258 - loss:   125.8415 Validation Accuracy: 0.886719
# Epoch 10, Batch 259 - loss:   300.5904 Validation Accuracy: 0.886719
# Epoch 10, Batch 260 - loss:   236.9186 Validation Accuracy: 0.886719
# Epoch 10, Batch 261 - loss:   259.9843 Validation Accuracy: 0.886719
# Epoch 10, Batch 262 - loss:   267.8491 Validation Accuracy: 0.886719
# Epoch 10, Batch 263 - loss:   116.2209 Validation Accuracy: 0.886719
# Epoch 10, Batch 264 - loss:   356.4229 Validation Accuracy: 0.886719
# Epoch 10, Batch 265 - loss:   436.3347 Validation Accuracy: 0.878906
# Epoch 10, Batch 266 - loss:   172.1114 Validation Accuracy: 0.878906
# Epoch 10, Batch 267 - loss:   217.3105 Validation Accuracy: 0.875000
# Epoch 10, Batch 268 - loss:   416.8765 Validation Accuracy: 0.878906
# Epoch 10, Batch 269 - loss:   364.0059 Validation Accuracy: 0.878906
# Epoch 10, Batch 270 - loss:   356.4792 Validation Accuracy: 0.875000
# Epoch 10, Batch 271 - loss:   296.9213 Validation Accuracy: 0.882812
# Epoch 10, Batch 272 - loss:   178.7390 Validation Accuracy: 0.886719
# Epoch 10, Batch 273 - loss:   368.5621 Validation Accuracy: 0.878906
# Epoch 10, Batch 274 - loss:   197.0324 Validation Accuracy: 0.878906
# Epoch 10, Batch 275 - loss:   225.3432 Validation Accuracy: 0.886719
# Epoch 10, Batch 276 - loss:   386.9524 Validation Accuracy: 0.886719
# Epoch 10, Batch 277 - loss:   237.4094 Validation Accuracy: 0.882812
# Epoch 10, Batch 278 - loss:   234.9144 Validation Accuracy: 0.886719
# Epoch 10, Batch 279 - loss:   230.2514 Validation Accuracy: 0.882812
# Epoch 10, Batch 280 - loss:   357.3493 Validation Accuracy: 0.882812
# Epoch 10, Batch 281 - loss:   183.6209 Validation Accuracy: 0.886719
# Epoch 10, Batch 282 - loss:   370.8808 Validation Accuracy: 0.890625
# Epoch 10, Batch 283 - loss:   205.4319 Validation Accuracy: 0.886719
# Epoch 10, Batch 284 - loss:   273.7287 Validation Accuracy: 0.890625
# Epoch 10, Batch 285 - loss:   327.5743 Validation Accuracy: 0.886719
# Epoch 10, Batch 286 - loss:   262.5780 Validation Accuracy: 0.886719
# Epoch 10, Batch 287 - loss:   529.8356 Validation Accuracy: 0.886719
# Epoch 10, Batch 288 - loss:   432.0438 Validation Accuracy: 0.886719
# Epoch 10, Batch 289 - loss:   534.0247 Validation Accuracy: 0.882812
# Epoch 10, Batch 290 - loss:   328.6861 Validation Accuracy: 0.882812
# Epoch 10, Batch 291 - loss:   310.3617 Validation Accuracy: 0.878906
# Epoch 10, Batch 292 - loss:   276.5105 Validation Accuracy: 0.882812
# Epoch 10, Batch 293 - loss:   296.8688 Validation Accuracy: 0.886719
# Epoch 10, Batch 294 - loss:   278.3847 Validation Accuracy: 0.886719
# Epoch 10, Batch 295 - loss:   454.7177 Validation Accuracy: 0.882812
# Epoch 10, Batch 296 - loss:   407.8856 Validation Accuracy: 0.878906
# Epoch 10, Batch 297 - loss:   202.3613 Validation Accuracy: 0.878906
# Epoch 10, Batch 298 - loss:   328.6529 Validation Accuracy: 0.882812
# Epoch 10, Batch 299 - loss:   301.3693 Validation Accuracy: 0.886719
# Epoch 10, Batch 300 - loss:   228.7238 Validation Accuracy: 0.882812
# Epoch 10, Batch 301 - loss:   312.3459 Validation Accuracy: 0.882812
# Epoch 10, Batch 302 - loss:   248.0157 Validation Accuracy: 0.882812
# Epoch 10, Batch 303 - loss:   385.1208 Validation Accuracy: 0.882812
# Epoch 10, Batch 304 - loss:   278.1700 Validation Accuracy: 0.886719
# Epoch 10, Batch 305 - loss:   263.7413 Validation Accuracy: 0.878906
# Epoch 10, Batch 306 - loss:   331.6225 Validation Accuracy: 0.878906
# Epoch 10, Batch 307 - loss:   426.1146 Validation Accuracy: 0.882812
# Epoch 10, Batch 308 - loss:   229.0379 Validation Accuracy: 0.882812
# Epoch 10, Batch 309 - loss:   549.4102 Validation Accuracy: 0.882812
# Epoch 10, Batch 310 - loss:   172.9346 Validation Accuracy: 0.878906
# Epoch 10, Batch 311 - loss:   222.9507 Validation Accuracy: 0.886719
# Epoch 10, Batch 312 - loss:   258.1721 Validation Accuracy: 0.878906
# Epoch 10, Batch 313 - loss:   291.5980 Validation Accuracy: 0.886719
# Epoch 10, Batch 314 - loss:   245.8646 Validation Accuracy: 0.882812
# Epoch 10, Batch 315 - loss:   175.9143 Validation Accuracy: 0.886719
# Epoch 10, Batch 316 - loss:   363.4075 Validation Accuracy: 0.890625
# Epoch 10, Batch 317 - loss:   270.1652 Validation Accuracy: 0.886719
# Epoch 10, Batch 318 - loss:   383.2784 Validation Accuracy: 0.886719
# Epoch 10, Batch 319 - loss:   235.7397 Validation Accuracy: 0.886719
# Epoch 10, Batch 320 - loss:   297.2127 Validation Accuracy: 0.886719
# Epoch 10, Batch 321 - loss:   262.0468 Validation Accuracy: 0.882812
# Epoch 10, Batch 322 - loss:   347.1396 Validation Accuracy: 0.886719
# Epoch 10, Batch 323 - loss:   303.0467 Validation Accuracy: 0.886719
# Epoch 10, Batch 324 - loss:   250.3400 Validation Accuracy: 0.886719
# Epoch 10, Batch 325 - loss:   257.2326 Validation Accuracy: 0.890625
# Epoch 10, Batch 326 - loss:   251.5946 Validation Accuracy: 0.886719
# Epoch 10, Batch 327 - loss:   254.0547 Validation Accuracy: 0.886719
# Epoch 10, Batch 328 - loss:   258.1819 Validation Accuracy: 0.886719
# Epoch 10, Batch 329 - loss:   296.3414 Validation Accuracy: 0.882812
# Epoch 10, Batch 330 - loss:   312.9626 Validation Accuracy: 0.894531
# Epoch 10, Batch 331 - loss:   228.7861 Validation Accuracy: 0.890625
# Epoch 10, Batch 332 - loss:   451.0624 Validation Accuracy: 0.882812
# Epoch 10, Batch 333 - loss:   443.7519 Validation Accuracy: 0.882812
# Epoch 10, Batch 334 - loss:   283.6798 Validation Accuracy: 0.882812
# Epoch 10, Batch 335 - loss:   318.5500 Validation Accuracy: 0.886719
# Epoch 10, Batch 336 - loss:   245.5397 Validation Accuracy: 0.882812
# Epoch 10, Batch 337 - loss:   198.6071 Validation Accuracy: 0.886719
# Epoch 10, Batch 338 - loss:   369.3337 Validation Accuracy: 0.886719
# Epoch 10, Batch 339 - loss:   183.3165 Validation Accuracy: 0.886719
# Epoch 10, Batch 340 - loss:   353.8111 Validation Accuracy: 0.886719
# Epoch 10, Batch 341 - loss:   254.1191 Validation Accuracy: 0.882812
# Epoch 10, Batch 342 - loss:   213.5533 Validation Accuracy: 0.882812
# Epoch 10, Batch 343 - loss:   253.3082 Validation Accuracy: 0.882812
# Epoch 10, Batch 344 - loss:   284.1321 Validation Accuracy: 0.882812
# Epoch 10, Batch 345 - loss:   289.2294 Validation Accuracy: 0.882812
# Epoch 10, Batch 346 - loss:   230.4918 Validation Accuracy: 0.882812
# Epoch 10, Batch 347 - loss:   244.4505 Validation Accuracy: 0.886719
# Epoch 10, Batch 348 - loss:   329.4041 Validation Accuracy: 0.882812
# Epoch 10, Batch 349 - loss:   199.1174 Validation Accuracy: 0.882812
# Epoch 10, Batch 350 - loss:   409.8160 Validation Accuracy: 0.882812
# Epoch 10, Batch 351 - loss:   229.0171 Validation Accuracy: 0.882812
# Epoch 10, Batch 352 - loss:   267.6962 Validation Accuracy: 0.886719
# Epoch 10, Batch 353 - loss:   296.3601 Validation Accuracy: 0.886719
# Epoch 10, Batch 354 - loss:   328.1381 Validation Accuracy: 0.886719
# Epoch 10, Batch 355 - loss:   315.8917 Validation Accuracy: 0.886719
# Epoch 10, Batch 356 - loss:   410.3623 Validation Accuracy: 0.886719
# Epoch 10, Batch 357 - loss:   247.5804 Validation Accuracy: 0.890625
# Epoch 10, Batch 358 - loss:   272.8977 Validation Accuracy: 0.886719
# Epoch 10, Batch 359 - loss:   188.3232 Validation Accuracy: 0.886719
# Epoch 10, Batch 360 - loss:   519.0627 Validation Accuracy: 0.886719
# Epoch 10, Batch 361 - loss:   301.4903 Validation Accuracy: 0.886719
# Epoch 10, Batch 362 - loss:   187.0168 Validation Accuracy: 0.886719
# Epoch 10, Batch 363 - loss:   172.8309 Validation Accuracy: 0.886719
# Epoch 10, Batch 364 - loss:   207.6979 Validation Accuracy: 0.886719
# Epoch 10, Batch 365 - loss:   187.6535 Validation Accuracy: 0.886719
# Epoch 10, Batch 366 - loss:   211.1787 Validation Accuracy: 0.886719
# Epoch 10, Batch 367 - loss:   174.2040 Validation Accuracy: 0.886719
# Epoch 10, Batch 368 - loss:   337.2831 Validation Accuracy: 0.898438
# Epoch 10, Batch 369 - loss:   186.4112 Validation Accuracy: 0.898438
# Epoch 10, Batch 370 - loss:   116.3680 Validation Accuracy: 0.894531
# Epoch 10, Batch 371 - loss:   192.7593 Validation Accuracy: 0.894531
# Epoch 10, Batch 372 - loss:   440.9186 Validation Accuracy: 0.898438
# Epoch 10, Batch 373 - loss:   524.1810 Validation Accuracy: 0.898438
# Epoch 10, Batch 374 - loss:   384.0298 Validation Accuracy: 0.890625
# Epoch 10, Batch 375 - loss:   342.7216 Validation Accuracy: 0.894531
# Epoch 10, Batch 376 - loss:   364.3845 Validation Accuracy: 0.894531
# Epoch 10, Batch 377 - loss:   221.8441 Validation Accuracy: 0.886719
# Epoch 10, Batch 378 - loss:   385.0799 Validation Accuracy: 0.886719
# Epoch 10, Batch 379 - loss:   276.6374 Validation Accuracy: 0.886719
# Epoch 10, Batch 380 - loss:   271.6196 Validation Accuracy: 0.886719
# Epoch 10, Batch 381 - loss:   314.1035 Validation Accuracy: 0.886719
# Epoch 10, Batch 382 - loss:   188.5718 Validation Accuracy: 0.890625
# Epoch 10, Batch 383 - loss:   193.6769 Validation Accuracy: 0.890625
# Epoch 10, Batch 384 - loss:   445.7719 Validation Accuracy: 0.890625
# Epoch 10, Batch 385 - loss:   139.1587 Validation Accuracy: 0.894531
# Epoch 10, Batch 386 - loss:   297.3432 Validation Accuracy: 0.890625
# Epoch 10, Batch 387 - loss:   351.7178 Validation Accuracy: 0.890625
# Epoch 10, Batch 388 - loss:   324.0079 Validation Accuracy: 0.890625
# Epoch 10, Batch 389 - loss:   264.1534 Validation Accuracy: 0.894531
# Epoch 10, Batch 390 - loss:   295.5619 Validation Accuracy: 0.894531
# Epoch 10, Batch 391 - loss:   274.6914 Validation Accuracy: 0.886719
# Epoch 10, Batch 392 - loss:   331.3108 Validation Accuracy: 0.886719
# Epoch 10, Batch 393 - loss:   273.4869 Validation Accuracy: 0.886719
# Epoch 10, Batch 394 - loss:   282.9916 Validation Accuracy: 0.886719
# Epoch 10, Batch 395 - loss:   284.9491 Validation Accuracy: 0.886719
# Epoch 10, Batch 396 - loss:   306.1426 Validation Accuracy: 0.878906
# Epoch 10, Batch 397 - loss:   423.0898 Validation Accuracy: 0.882812
# Epoch 10, Batch 398 - loss:   267.2545 Validation Accuracy: 0.886719
# Epoch 10, Batch 399 - loss:   151.5317 Validation Accuracy: 0.890625
# Epoch 10, Batch 400 - loss:   419.7011 Validation Accuracy: 0.890625
# Epoch 10, Batch 401 - loss:   193.6297 Validation Accuracy: 0.890625
# Epoch 10, Batch 402 - loss:   347.8024 Validation Accuracy: 0.890625
# Epoch 10, Batch 403 - loss:   323.9570 Validation Accuracy: 0.890625
# Epoch 10, Batch 404 - loss:   357.8617 Validation Accuracy: 0.890625
# Epoch 10, Batch 405 - loss:   189.5323 Validation Accuracy: 0.890625
# Epoch 10, Batch 406 - loss:   401.4372 Validation Accuracy: 0.890625
# Epoch 10, Batch 407 - loss:   352.9293 Validation Accuracy: 0.890625
# Epoch 10, Batch 408 - loss:   214.9470 Validation Accuracy: 0.890625
# Epoch 10, Batch 409 - loss:   143.9100 Validation Accuracy: 0.882812
# Epoch 10, Batch 410 - loss:   322.4162 Validation Accuracy: 0.886719
# Epoch 10, Batch 411 - loss:   245.4176 Validation Accuracy: 0.886719
# Epoch 10, Batch 412 - loss:   318.0443 Validation Accuracy: 0.890625
# Epoch 10, Batch 413 - loss:   317.7192 Validation Accuracy: 0.890625
# Epoch 10, Batch 414 - loss:   309.2146 Validation Accuracy: 0.890625
# Epoch 10, Batch 415 - loss:   162.6880 Validation Accuracy: 0.890625
# Epoch 10, Batch 416 - loss:   102.3750 Validation Accuracy: 0.894531
# Epoch 10, Batch 417 - loss:   248.7333 Validation Accuracy: 0.894531
# Epoch 10, Batch 418 - loss:   226.2339 Validation Accuracy: 0.894531
# Epoch 10, Batch 419 - loss:   253.3939 Validation Accuracy: 0.890625
# Epoch 10, Batch 420 - loss:   446.6804 Validation Accuracy: 0.890625
# Epoch 10, Batch 421 - loss:   425.1639 Validation Accuracy: 0.890625
# Epoch 10, Batch 422 - loss:   193.0392 Validation Accuracy: 0.890625
# Epoch 10, Batch 423 - loss:   285.6461 Validation Accuracy: 0.894531
# Epoch 10, Batch 424 - loss:   128.8333 Validation Accuracy: 0.894531
# Epoch 10, Batch 425 - loss:   291.0107 Validation Accuracy: 0.894531
# Epoch 10, Batch 426 - loss:   306.7544 Validation Accuracy: 0.898438
# Epoch 10, Batch 427 - loss:   324.9343 Validation Accuracy: 0.894531
# Epoch 10, Batch 428 - loss:   408.4852 Validation Accuracy: 0.894531
# Epoch 10, Batch 429 - loss:   198.9642 Validation Accuracy: 0.894531
# Testing Accuracy: 0.88671875

# %%
# TensorFlow for CNN with buildin high level API

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

mnist = input_data.read_data_sets("./mnist", one_hot=True, reshape=False)

# parameters
learning_rate = 0.001
epochs = 10
batch_size = 128

# number of samples to calculate validation and accuracy
test_valid_size = 256

# network parameters
n_classes = 10
dropout = tf.placeholder(tf.float32)

# Input and target placeholders
inputs_ = tf.placeholder(tf.float32, (None, 28, 28, 1))
targets_ = tf.placeholder(tf.float32)

# build the conv2d graph with tf.layers.conv2d and tf.layers.max_pooling2d
# layer 1 - 28*28*1 to 14*14*32
conv1 = tf.layers.conv2d(inputs_, 32, (5, 5), padding='same', activation=tf.nn.relu)
maxpool1 = tf.layers.max_pooling2d(conv1, (2, 2), (2, 2))

# layer 2 - 14*14*32 to 7*7*64
conv2 = tf.layers.conv2d(maxpool1, 64, (5, 5), padding='same', activation=tf.nn.relu)
maxpool2 = tf.layers.max_pooling2d(conv2, (2, 2), (2, 2))

# Fully connected layer
flattened = tf.reshape(maxpool2, [-1, 7*7*64])
fc1 = tf.layers.dense(flattened, units=1024, activation=tf.nn.relu)
fc1 = tf.layers.dropout(fc1, rate=dropout)

# output logits
logits = tf.layers.dense(fc1, units=n_classes)

# define loss and optimizer
cost = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=targets_))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)\
    .minimize(cost)

# accuracy
correct_pred = tf.equal(tf.argmax(logits, axis=1), tf.argmax(targets_, axis=1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# initializing the viriables
init = tf.global_variables_initializer()

# launch the graph
with tf.Session() as sess:
    sess.run(init)

    for epoch in range(epochs):
        for batch in range(mnist.train.num_examples//batch_size):
            batch_x, batch_y = mnist.train.next_batch(batch_size)
            sess.run(optimizer, feed_dict={
                inputs_: batch_x,
                targets_: batch_y,
                dropout: 0.75})

            # calculate batch loss and accuracy
            loss = sess.run(cost, feed_dict={
                inputs_: batch_x,
                targets_: batch_y,
                dropout: 1.})
            valid_acc = sess.run(accuracy, feed_dict={
                inputs_: mnist.validation.images[:test_valid_size],
                targets_: mnist.validation.labels[:test_valid_size],
                dropout: 1.})

            print('Epoch {:>2}, Batch {:>3} - loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                  epoch + 1,
                  batch + 1,
                  loss,
                  valid_acc))

        test_acc = sess.run(accuracy, feed_dict={
            inputs_: mnist.test.images[:test_valid_size],
            targets_: mnist.test.labels[:test_valid_size],
            dropout: 1.})
        print('Testing Accuracy: {}'.format(test_acc))

# %%
# TensorFlow for RNN
# this cell's code is adopted from 
# https://jasdeep06.github.io/posts/Understanding-LSTM-in-Tensorflow-MNIST/

import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("./mnist", one_hot=True)

# define constant
# the 28 x 28 lengh input data is unrolled into 28 time steps
time_steps = 28
# hidden LSTM units
num_units = 128
# rows of 28 pixels
n_inputs = 28
# learning rate for Adam
learning_rate = 0.001
# there are 10 classes in the labels
n_classes = 10
# batch_size
batch_size = 128

# weights and biases for output layer
out_weights = tf.Variable(tf.random_normal([num_units, n_classes]))
out_bias = tf.Variable(tf.random_normal([n_classes]))

# defining inputs and labels placeholders
x = tf.placeholder(tf.float32, [None, time_steps, n_inputs])
y = tf.placeholder(tf.float32, [None, n_classes])

# processing the input tensor from [batch_size, time_steps, n_input] to 
# a 'time_steps' length list of [batch_size, n_input] tensors
input = tf.unstack(x, time_steps, 1)

# defining the network
lstm_layer = tf.contrib.rnn.BasicLSTMCell(num_units, forget_bias=1)
outputs, _ = tf.contrib.rnn.static_rnn(lstm_layer, input, dtype=tf.float32)

# converting last output of dimension [batch_size, num_units] to 
# [batch_size, n_classes] with matrix multplication
prediction = tf.matmul(outputs[-1], out_weights) + out_bias

# defining loss and optimization
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# model evaluation
correct_prediction = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# train the model
init = tf.global_variables_initializer()
with tf.Session() as sess:
    sess.run(init)
    iter = 1
    while iter < 800:
        batch_x, batch_y = mnist.train.next_batch(batch_size=batch_size)
        batch_x = batch_x.reshape((batch_size, time_steps, n_inputs))
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        
        if iter % 10 == 0:
            acc = sess.run(accuracy, feed_dict={x: batch_x, y: batch_y})
            losses = sess.run(loss, feed_dict={x: batch_x, y: batch_y})
            print("For iter ", iter)
            print("Accuracy ", acc)
            print("Loss ", losses)
            print("___________________")
        iter += 1
        
        test_data = mnist.test.images[:128].reshape((-1, time_steps, n_input))
        test_label = mnist.test.labels[:128]
        print("Test Accuracy ", sess.run(acc, feed_dict={x: test_data, y: test_label}))
# Out:
# Extracting ./mnist\train-images-idx3-ubyte.gz
# Extracting ./mnist\train-labels-idx1-ubyte.gz
# Extracting ./mnist\t10k-images-idx3-ubyte.gz
# Extracting ./mnist\t10k-labels-idx1-ubyte.gz
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ff6730ef47ba> in <module>()
#      46
#      47 # model evaluation
# ---> 48 correct_prediction = tf.equal(tf.argmax(prediciton, 1), tf.argmax(y, 1))
#      49 accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
#      50
#
# NameError: name 'prediciton' is not defined
